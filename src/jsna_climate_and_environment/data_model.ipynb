# %% [markdown]
# # The tableau data model will minimize data duplication and keep dashboards small
#
# The data model will require:
# - each area polygon for the current year
# - the metadata for each indicator
# - the demographic breakdown for each indicator
# - the time_range for each indicator
#
# indicator_fact
# - id
# - area_id
# - metadata_id
# - population_id
# - time_range_id
# - value
# - error_margin
#
# area_dim
# - id
# - name
# - type
# - source_url
# - parent_district: str | None
# - parent_lgr: str | None
# - geometry
#
# metadata_dim
# - id
# - name
# - description
# - source_system
# - source_identifier | optional
# - type_of_value
# - max_value
# - min_value
# - missing_value_description
#
# population_dim
# - population_id
# - name
# - description
# - source
# - date_recorded
# - count
# - date_updated

# %% [markdown]
# indicator_fact
# - id
# - area_code
# - indicator_dimension
# - numerator
# - denominator
# - value
# - lower
# - upper
#
# area_layer
# - code
# - name
# - type
# - geometry
#
# area_metadata
# - type
# - source_url
#
# area_linking
# - area_code
# - \[types\]
#
# indicator_dimension
# - id
# - indicator_name
# - area_type \[lsoa | msoa | district\] \[pcn | place | sicbl\]
# - date
# - notes
# - numerator_description
# - denominator_description
# - value_description
# - lower_description
# - upper_description
# - surrey_numerator
# - surrey_denominator
# - surrey_value
# - surrey_lower
# - surrey_upper
# - england_numerator
# - england_denominator
# - england_value
# - england_lower
# - england_upper
# - description
# - source
