# %%
from arcgis.gis import GIS, Item
from arcgis.features import FeatureLayer, FeatureSet
import geopandas as gpd


# Connect to a public server (anonymous)
public_gis = GIS() # 1. Connect and access your layers



county_layer = FeatureLayer("https://services.arcgis.com/Lq3V5RFuTBC9I7kv/ArcGIS/rest/services/annual_count_of_extreme_summer_days_projections_sub_local_authority_v1/FeatureServer")
lsoa_layer = FeatureLayer("URL_TO_LSOA_SERVICE")

# 2. Get the specific county geometry
# Replace 'CountyName' with your actual field and value
county_fs = county_layer.query(where="NAME = 'Hertfordshire'")
county_geom = county_fs.features[0].geometry

# 3. Create the spatial filter
# 'intersects' catches any LSOA touching the boundary
spatial_filter = filters.intersects(geometry=county_geom, sr=county_layer.properties.spatialReference)

def read_featureset(feature_set: FeatureSet) -> gpd.GeoDataFrame:
    return gpd.read_file(feature_set.to_geojson, driver="GEOJSON")

def get_feature_layer_by_name(name: str, layer: int=0) -> FeatureLayer:
    items: list[Item] = public_gis.content.search(f"name:{name}")
    if len(items) != 1:
        raise Exception(f"searching for dataset '{name}' returned 0 results")
    return items[0]


# Querying returns a FeatureSet which is well-typed for further processing
results = read_featureset(
    get_feature_layer_by_name("annual_count_of_extreme_summer_days_projections_sub_local_authority_v1")
    .query(where="1=1")
)

# %%
from arcgis import GIS
gis = GIS("https://gis.surreycc.gov.uk/portal")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File d:\nmolkent\code\scc_jsna\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File d:\nmolkent\code\scc_jsna\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File d:\nmolkent\code\scc_jsna\.venv\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     794 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...

# %%
gis

# %%
get_item("annual_count_of_extreme_summer_days_projections_sub_local_authority_v1").download(".")
# Out:
# '.\\annual_count_of_extreme_summer_days_projections_sub_local_authority_v1'

# %%
FeatureLayer("https://services.arcgis.com/Lq3V5RFuTBC9I7kv/ArcGIS/rest/services/annual_count_of_extreme_summer_days_projections_sub_local_authority_v1/FeatureServer/0").query("1=1")
# Out:
# d:\nmolkent\code\scc_jsna\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'services.arcgis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# d:\nmolkent\code\scc_jsna\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'services.arcgis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# d:\nmolkent\code\scc_jsna\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'services.arcgis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
